# %%
# Importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
PROJECT_ROOT = Path.cwd().parent
DATA_DIR = PROJECT_ROOT / "data"

DATA_DIR
# Out:
# PosixPath('/Users/shuprov630/canhealth-analytics/data')

# %%
#Loading tables

hospitals = pd.read_csv(DATA_DIR / "dim_hospitals.csv")
procedures = pd.read_csv(DATA_DIR / "dim_procedures.csv")
periods = pd.read_csv(DATA_DIR / "dim_periods.csv")
financials = pd.read_csv(DATA_DIR / "fact_financials.csv")
wait_times = pd.read_csv(DATA_DIR / "fact_wait_times.csv")

# %%
# checking the shape of the tables

print("Hospitals:", hospitals.shape)
print("Procedures:", procedures.shape)
print("Periods:", periods.shape)
print("Wait times:", wait_times.shape)
print("Financials:", financials.shape)
# Out:
# Hospitals: (150, 10)
# Procedures: (8, 8)
# Periods: (10, 5)
# Wait times: (7910, 9)
# Financials: (1500, 9)

# %%
wait_times.head()
# Out:
#    record_id  hospital_id  procedure_id  period_id  patient_count  \
# 0          1            1             1          1            117
# 1          2            1             1          2             98
# 2          3            1             1          3            107
# 3          4            1             1          4             78
# 4          5            1             1          5             57
#
#    p50_wait_days  p90_wait_days  pct_within_benchmark data_completeness
# 0          155.5          260.5                  66.2          Complete
# 1           91.8          187.9                  94.0          Complete
# 2          133.9          225.2                  74.3          Complete
# 3          119.6          250.0                  58.8           Partial
# 4          127.3          214.9                  82.4          Complete

# %%
wait_times.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7910 entries, 0 to 7909
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   record_id             7910 non-null   int64
#  1   hospital_id           7910 non-null   int64
#  2   procedure_id          7910 non-null   int64
#  3   period_id             7910 non-null   int64
#  4   patient_count         7910 non-null   int64
#  5   p50_wait_days         7910 non-null   float64
#  6   p90_wait_days         7910 non-null   float64
#  7   pct_within_benchmark  7910 non-null   float64
#  8   data_completeness     7910 non-null   object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 556.3+ KB

# %%
wait_times.describe()
# Out:
#          record_id  hospital_id  procedure_id    period_id  patient_count  \
# count  7910.000000  7910.000000   7910.000000  7910.000000    7910.000000
# mean   3955.500000    78.278129      4.720607     5.500000     153.750316
# std    2283.564648    44.415520      2.415143     2.872463     138.583291
# min       1.000000     1.000000      1.000000     1.000000       6.000000
# 25%    1978.250000    40.000000      2.000000     3.000000      58.000000
# 50%    3955.500000    82.000000      5.000000     5.500000     117.000000
# 75%    5932.750000   118.000000      7.000000     8.000000     198.000000
# max    7910.000000   150.000000      8.000000    10.000000    1056.000000
#
#        p50_wait_days  p90_wait_days  pct_within_benchmark
# count    7910.000000    7910.000000           7910.000000
# mean       50.762946      96.852743             73.467686
# std        50.137952      95.147637             14.803476
# min         0.800000       1.700000             26.300000
# ...

# %%
# Checking for Null values in the wait_times dataset
wait_times.isna().sum()
# Out:
# record_id               0
# hospital_id             0
# procedure_id            0
# period_id               0
# patient_count           0
# p50_wait_days           0
# p90_wait_days           0
# pct_within_benchmark    0
# data_completeness       0
# dtype: int64

# %% [markdown]
# No Null values are present

# %%
# checking for Null values in the hospitals dataset
hospitals.isna().sum()
# Out:
# hospital_id         0
# hospital_name       0
# province_code       0
# province_name       0
# health_region       0
# city                0
# hospital_type       0
# urban_rural         0
# bed_count           0
# established_year    0
# dtype: int64

# %% [markdown]
# No Null values present in hospital_dataset

# %%
#Checking for duplicates in the wait_times dataset

wait_times["record_id"].duplicated().sum()
# Out:
# 0

# %%
# checking for duplicates in the hospitals dataset
hospitals["hospital_id"].duplicated().sum()
# Out:
# 0
